# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 600

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
print("Beginning data retrieval..." + "\n" + "-----")
cit_num = 1
clouds = []
country = []
date = []
humidity = []
lat = []
lng = []
maxtemp = []
wind = []
weathercheck = [clouds, country, date, humidity, lat, lng, maxtemp, wind]
for city in cities:
    url = "http://api.openweathermap.org/data/2.5/weather?"
    units = "imperial"
    query_url = url + "appid=" + api_key + "&units=" + units + "&q=" + city
    weather = requests.get(query_url).json()
    try:
        #weather = requests.get(query_url).json()
        print(f"Retrieving city #{cit_num}: {city}")
        clouds.append(weather['clouds']['all'])
        country.append(weather['sys']['country'])
        date.append(weather['dt'])
        humidity.append(weather['main']['humidity'])
        lat.append(weather['coord']['lat'])
        lng.append(weather['coord']['lon'])
        maxtemp.append(weather['main']['temp_max'])
        wind.append(weather['wind']['speed'])     
               
    except KeyError:
        country.append(np.nan)
        date.append(np.nan)
        humidity.append(np.nan)
        lat.append(np.nan)
        lng.append(np.nan)
        maxtemp.append(np.nan)
        wind.append(np.nan)
        clouds.append(0)

    cit_num = cit_num + 1   
print("-----" + "\n" + "Data retrieval complete.")
# Out:
# Beginning data retrieval...
# -----
# Retrieving city #1: castro
# Retrieving city #2: saint-philippe
# Retrieving city #3: tsihombe
# Retrieving city #4: rikitea
# Retrieving city #5: hilo
# Retrieving city #6: hermanus
# Retrieving city #7: nikolskoye
# Retrieving city #8: cape town
# Retrieving city #9: malakal
# Retrieving city #10: tuktoyaktuk
# Retrieving city #11: hofn
# Retrieving city #12: buariki
# Retrieving city #13: cidreira
# Retrieving city #14: longyearbyen
# Retrieving city #15: bengkulu
# Retrieving city #16: amderma
# Retrieving city #17: atuona
# Retrieving city #18: seymchan
# Retrieving city #19: punta alta
# Retrieving city #20: atar
# Retrieving city #21: buchanan
# Retrieving city #22: port blair
# Retrieving city #23: palabuhanratu
# Retrieving city #24: groningen
# Retrieving city #25: puerto ayora
# Retrieving city #26: leh
# Retrieving city #27: norman wells
# Retrieving city #28: popondetta
# Retrieving city #29: jamestown
# Retrieving city #30: sakakah
# Retrieving city #31: saint george
# Retrieving city #32: hasaki
# Retrieving city #33: kyra
# Retrieving city #34: meulaboh
# Retrieving city #35: dikson
# Retrieving city #36: antalaha
# Retrieving city #37: qaanaaq
# Retrieving city #38: kruisfontein
# Retrieving city #39: cabo san lucas
# Retrieving city #40: alofi
# Retrieving city #41: tiksi
# Retrieving city #42: saint-augustin
# Retrieving city #43: mar del plata
# Retrieving city #44: teahupoo
# Retrieving city #45: quatre cocos
# Retrieving city #46: tabiauea
# Retrieving city #47: shiyan
# Retrieving city #48: merauke
# Retrieving city #49: georgetown
# Retrieving city #50: thilogne
# Retrieving city #51: taguatinga
# Retrieving city #52: leningradskiy
# Retrieving city #53: chuy
# Retrieving city #54: busselton
# Retrieving city #55: barrow
# Retrieving city #56: punta arenas
# Retrieving city #57: palmer
# Retrieving city #58: taolanaro
# Retrieving city #59: ushuaia
# Retrieving city #60: new norfolk
# Retrieving city #61: hobart
# Retrieving city #62: sorong
# Retrieving city #63: jalu
# Retrieving city #64: zyryanka
# Retrieving city #65: kaitangata
# Retrieving city #66: guerrero negro
# Retrieving city #67: bredasdorp
# Retrieving city #68: havelock
# Retrieving city #69: emerald
# Retrieving city #70: grand river south east
# Retrieving city #71: kapaa
# Retrieving city #72: samarai
# Retrieving city #73: sentyabrskiy
# Retrieving city #74: kavieng
# Retrieving city #75: bakchar
# Retrieving city #76: hithadhoo
# Retrieving city #77: luwuk
# Retrieving city #78: bethel
# Retrieving city #79: isiro
# Retrieving city #80: bluff
# Retrieving city #81: huambo
# Retrieving city #82: artyk
# Retrieving city #83: severo-kurilsk
# Retrieving city #84: yulara
# Retrieving city #85: isilkul
# Retrieving city #86: villamontes
# Retrieving city #87: seoul
# Retrieving city #88: jacareacanga
# Retrieving city #89: albany
# Retrieving city #90: klaksvik
# Retrieving city #91: thompson
# Retrieving city #92: siavonga
# Retrieving city #93: faanui
# Retrieving city #94: deputatskiy
# Retrieving city #95: palu
# Retrieving city #96: tiffin
# Retrieving city #97: ahipara
# Retrieving city #98: isangel
# Retrieving city #99: havoysund
# Retrieving city #100: banda aceh
# Retrieving city #101: port keats
# Retrieving city #102: sovetskiy
# Retrieving city #103: codrington
# Retrieving city #104: esperance
# Retrieving city #105: trincomalee
# Retrieving city #106: port elizabeth
# Retrieving city #107: mayo
# Retrieving city #108: mataura
# Retrieving city #109: krasnyy chikoy
# Retrieving city #110: port alfred
# Retrieving city #111: port lincoln
# Retrieving city #112: kapoeta
# Retrieving city #113: sigli
# Retrieving city #114: hambantota
# Retrieving city #115: along
# Retrieving city #116: kuusamo
# Retrieving city #117: barentsburg
# Retrieving city #118: santa eulalia del rio
# Retrieving city #119: butaritari
# Retrieving city #120: sri aman
# Retrieving city #121: kununurra
# Retrieving city #122: gobabis
# Retrieving city #123: jutai
# Retrieving city #124: birjand
# Retrieving city #125: vaitupu
# Retrieving city #126: avarua
# Retrieving city #127: pacora
# Retrieving city #128: shitanjing
# Retrieving city #129: zhigansk
# Retrieving city #130: saskylakh
# Retrieving city #131: nome
# Retrieving city #132: chokurdakh
# Retrieving city #133: coffs harbour
# Retrieving city #134: liverpool
# Retrieving city #135: magalia
# Retrieving city #136: tungkang
# Retrieving city #137: ferrol
# Retrieving city #138: luderitz
# Retrieving city #139: sao filipe
# Retrieving city #140: saint-francois
# Retrieving city #141: antofagasta
# Retrieving city #142: berdigestyakh
# Retrieving city #143: pulivendla
# Retrieving city #144: naze
# Retrieving city #145: ribeira grande
# Retrieving city #146: makubetsu
# Retrieving city #147: khatanga
# Retrieving city #148: aljezur
# Retrieving city #149: port hardy
# Retrieving city #150: okhotsk
# Retrieving city #151: batagay-alyta
# Retrieving city #152: matagami
# Retrieving city #153: san cristobal
# Retrieving city #154: emirdag
# Retrieving city #155: lardos
# Retrieving city #156: brae
# Retrieving city #157: grindavik
# Retrieving city #158: arraial do cabo
# Retrieving city #159: fairbanks
# Retrieving city #160: katsuura
# Retrieving city #161: lebu
# Retrieving city #162: souillac
# Retrieving city #163: bubaque
# Retrieving city #164: asyut
# Retrieving city #165: port macquarie
# Retrieving city #166: lebyazhye
# Retrieving city #167: sao joao da barra
# Retrieving city #168: rolim de moura
# Retrieving city #169: kamenskoye
# Retrieving city #170: cherskiy
# Retrieving city #171: mahebourg
# Retrieving city #172: jumla
# Retrieving city #173: touros
# Retrieving city #174: oum hadjer
# Retrieving city #175: ocos
# Retrieving city #176: malanje
# Retrieving city #177: labuhan
# Retrieving city #178: gazanjyk
# Retrieving city #179: mys shmidta
# Retrieving city #180: iskateley
# Retrieving city #181: ancud
# Retrieving city #182: east london
# Retrieving city #183: kieta
# Retrieving city #184: yanam
# Retrieving city #185: roald
# Retrieving city #186: pevek
# Retrieving city #187: tumannyy
# Retrieving city #188: te anau
# Retrieving city #189: olafsvik
# Retrieving city #190: usinsk
# Retrieving city #191: marawi
# Retrieving city #192: jizan
# Retrieving city #193: illoqqortoormiut
# Retrieving city #194: kupang
# Retrieving city #195: rabak
# Retrieving city #196: sira
# Retrieving city #197: nguiu
# Retrieving city #198: taltal
# Retrieving city #199: bukachacha
# Retrieving city #200: mpulungu
# Retrieving city #201: tocantins
# Retrieving city #202: san policarpo
# Retrieving city #203: saleaula
# Retrieving city #204: upernavik
# Retrieving city #205: sattankulam
# Retrieving city #206: bilma
# Retrieving city #207: azimur
# Retrieving city #208: abu samrah
# Retrieving city #209: louisbourg
# Retrieving city #210: nizhneyansk
# Retrieving city #211: north bend
# Retrieving city #212: kegayli
# Retrieving city #213: rena
# Retrieving city #214: tubruq
# Retrieving city #215: vaini
# Retrieving city #216: portland
# Retrieving city #217: los llanos de aridane
# Retrieving city #218: maldonado
# Retrieving city #219: lusambo
# Retrieving city #220: broken hill
# Retrieving city #221: lata
# Retrieving city #222: jurado
# Retrieving city #223: teya
# Retrieving city #224: laurel
# Retrieving city #225: kokoda
# Retrieving city #226: yellowknife
# Retrieving city #227: iqaluit
# Retrieving city #228: zamora
# Retrieving city #229: provideniya
# Retrieving city #230: santiago
# Retrieving city #231: moose factory
# Retrieving city #232: yatsuo
# Retrieving city #233: hede
# Retrieving city #234: itarema
# Retrieving city #235: almaznyy
# Retrieving city #236: college
# Retrieving city #237: bambous virieux
# Retrieving city #238: camacha
# Retrieving city #239: huanren
# Retrieving city #240: victoria
# Retrieving city #241: caravelas
# Retrieving city #242: belushya guba
# Retrieving city #243: attawapiskat
# Retrieving city #244: asopos
# Retrieving city #245: coolum beach
# Retrieving city #246: tiznit
# Retrieving city #247: ponta do sol
# Retrieving city #248: lagos
# Retrieving city #249: karamea
# Retrieving city #250: birecik
# Retrieving city #251: nouakchott
# Retrieving city #252: ambilobe
# Retrieving city #253: urumqi
# Retrieving city #254: jiehu
# Retrieving city #255: kurdzhinovo
# Retrieving city #256: bograd
# Retrieving city #257: ha tinh
# Retrieving city #258: carnarvon
# Retrieving city #259: nuuk
# Retrieving city #260: abha
# Retrieving city #261: kristiinankaupunki
# Retrieving city #262: saldanha
# Retrieving city #263: tsarychanka
# Retrieving city #264: linhares
# Retrieving city #265: pauini
# Retrieving city #266: villa carlos paz
# Retrieving city #267: grand gaube
# Retrieving city #268: marsa matruh
# Retrieving city #269: chandbali
# Retrieving city #270: marcona
# Retrieving city #271: sagua de tanamo
# Retrieving city #272: kutum
# Retrieving city #273: west wendover
# Retrieving city #274: hobyo
# Retrieving city #275: conceicao do araguaia
# Retrieving city #276: macon
# Retrieving city #277: dunedin
# Retrieving city #278: ambon
# Retrieving city #279: santa fe
# Retrieving city #280: schattdorf
# Retrieving city #281: chicama
# Retrieving city #282: kahului
# Retrieving city #283: toliary
# Retrieving city #284: sistranda
# Retrieving city #285: cervo
# Retrieving city #286: trelew
# Retrieving city #287: kaitong
# Retrieving city #288: tasiilaq
# Retrieving city #289: gambela
# Retrieving city #290: lavrentiya
# Retrieving city #291: port antonio
# Retrieving city #292: saint-denis
# Retrieving city #293: kati
# Retrieving city #294: vila do maio
# Retrieving city #295: mao
# Retrieving city #296: acapulco
# Retrieving city #297: charlestown
# Retrieving city #298: cockburn town
# Retrieving city #299: tilichiki
# Retrieving city #300: tura
# Retrieving city #301: norrtalje
# Retrieving city #302: sandakan
# Retrieving city #303: talnakh
# Retrieving city #304: indianola
# Retrieving city #305: vao
# Retrieving city #306: hammerfest
# Retrieving city #307: umm kaddadah
# Retrieving city #308: riyadh
# Retrieving city #309: abu dhabi
# Retrieving city #310: tuatapere
# Retrieving city #311: lasa
# Retrieving city #312: hualmay
# Retrieving city #313: saint-georges
# Retrieving city #314: jaitaran
# Retrieving city #315: beziers
# Retrieving city #316: pisco
# Retrieving city #317: airai
# Retrieving city #318: lake city
# Retrieving city #319: tocopilla
# Retrieving city #320: vestmanna
# Retrieving city #321: cayenne
# Retrieving city #322: morshansk
# Retrieving city #323: hamilton
# Retrieving city #324: ouargaye
# Retrieving city #325: flinders
# Retrieving city #326: shirgaon
# Retrieving city #327: altay
# Retrieving city #328: cordoba
# Retrieving city #329: linxia
# Retrieving city #330: porto belo
# Retrieving city #331: torbay
# Retrieving city #332: avera
# Retrieving city #333: axim
# Retrieving city #334: inongo
# Retrieving city #335: olinda
# Retrieving city #336: tessalit
# Retrieving city #337: sale
# Retrieving city #338: beian
# Retrieving city #339: amursk
# Retrieving city #340: launceston
# Retrieving city #341: sitka
# Retrieving city #342: ballina
# Retrieving city #343: xining
# Retrieving city #344: kodiak
# Retrieving city #345: sturgeon bay
# Retrieving city #346: tselinnoye
# Retrieving city #347: gamba
# Retrieving city #348: carutapera
# Retrieving city #349: namatanai
# Retrieving city #350: ravar
# Retrieving city #351: bend
# Retrieving city #352: west plains
# Retrieving city #353: japura
# Retrieving city #354: sokolo
# Retrieving city #355: shimoda
# Retrieving city #356: cam ranh
# Retrieving city #357: carballo
# Retrieving city #358: clyde river
# Retrieving city #359: beyla
# Retrieving city #360: arvika
# Retrieving city #361: praia da vitoria
# Retrieving city #362: bosanski novi
# Retrieving city #363: salme
# Retrieving city #364: methoni
# Retrieving city #365: prince rupert
# Retrieving city #366: valley station
# Retrieving city #367: virginia beach
# Retrieving city #368: burica
# Retrieving city #369: yumen
# Retrieving city #370: speightstown
# Retrieving city #371: colares
# Retrieving city #372: talakan
# Retrieving city #373: visby
# Retrieving city #374: nanakuli
# Retrieving city #375: kargasok
# Retrieving city #376: paita
# Retrieving city #377: dingle
# Retrieving city #378: andenes
# Retrieving city #379: palm beach
# Retrieving city #380: ngama
# Retrieving city #381: podgornoye
# Retrieving city #382: dauphin
# Retrieving city #383: ogaminana
# Retrieving city #384: abnub
# Retrieving city #385: taitung
# Retrieving city #386: lima
# Retrieving city #387: roma
# Retrieving city #388: cabedelo
# Retrieving city #389: muros
# Retrieving city #390: paamiut
# Retrieving city #391: fortuna
# Retrieving city #392: saint-pierre
# Retrieving city #393: nyurba
# Retrieving city #394: ostrovnoy
# Retrieving city #395: jalapa
# Retrieving city #396: tual
# Retrieving city #397: nevel
# Retrieving city #398: amahai
# Retrieving city #399: el alto
# Retrieving city #400: vardo
# Retrieving city #401: terrace bay
# Retrieving city #402: genhe
# Retrieving city #403: payson
# Retrieving city #404: catarman
# Retrieving city #405: mount gambier
# Retrieving city #406: yatou
# Retrieving city #407: general roca
# Retrieving city #408: novyye burasy
# Retrieving city #409: moche
# Retrieving city #410: geraldton
# Retrieving city #411: barranca
# Retrieving city #412: nanortalik
# Retrieving city #413: tateyama
# Retrieving city #414: bonaventure
# Retrieving city #415: dzaoudzi
# Retrieving city #416: jay
# Retrieving city #417: luba
# Retrieving city #418: mehamn
# Retrieving city #419: fare
# Retrieving city #420: ketchikan
# Retrieving city #421: silvan
# Retrieving city #422: presidencia roque saenz pena
# Retrieving city #423: lamu
# Retrieving city #424: manakara
# Retrieving city #425: phan thiet
# Retrieving city #426: pundaguitan
# Retrieving city #427: tinaquillo
# Retrieving city #428: zeya
# Retrieving city #429: santana
# Retrieving city #430: gornopravdinsk
# Retrieving city #431: susanville
# Retrieving city #432: belmonte
# Retrieving city #433: lagunas
# Retrieving city #434: salalah
# Retrieving city #435: beringovskiy
# Retrieving city #436: formosa
# Retrieving city #437: pangnirtung
# Retrieving city #438: alappuzha
# Retrieving city #439: barcelos
# Retrieving city #440: zaysan
# Retrieving city #441: sisimiut
# Retrieving city #442: baykit
# Retrieving city #443: margate
# Retrieving city #444: paopao
# Retrieving city #445: san quintin
# Retrieving city #446: aklavik
# Retrieving city #447: zolotinka
# Retrieving city #448: rehoboth
# Retrieving city #449: quimper
# Retrieving city #450: cotacachi
# Retrieving city #451: prieska
# Retrieving city #452: dhidhdhoo
# Retrieving city #453: shubarkuduk
# Retrieving city #454: lazaro cardenas
# Retrieving city #455: kungurtug
# Retrieving city #456: acajutla
# Retrieving city #457: pangody
# Retrieving city #458: itatskiy
# Retrieving city #459: alencon
# Retrieving city #460: imbituba
# Retrieving city #461: millau
# Retrieving city #462: biloxi
# Retrieving city #463: borovoy
# Retrieving city #464: noumea
# Retrieving city #465: ninh binh
# Retrieving city #466: balkhash
# Retrieving city #467: falmouth
# Retrieving city #468: tottori
# Retrieving city #469: upata
# Retrieving city #470: severodvinsk
# Retrieving city #471: yinchuan
# Retrieving city #472: san jose
# Retrieving city #473: bandarbeyla
# Retrieving city #474: namibe
# Retrieving city #475: sinnai
# Retrieving city #476: mount isa
# Retrieving city #477: weyburn
# Retrieving city #478: huinan
# Retrieving city #479: ruatoria
# Retrieving city #480: nacala
# Retrieving city #481: tupancireta
# Retrieving city #482: sungairaya
# Retrieving city #483: pasinler
# Retrieving city #484: yerbogachen
# Retrieving city #485: aras
# Retrieving city #486: araouane
# Retrieving city #487: arrecife
# Retrieving city #488: saint anthony
# Retrieving city #489: samusu
# Retrieving city #490: umzimvubu
# Retrieving city #491: skelleftea
# Retrieving city #492: sujawal
# Retrieving city #493: pointe michel
# Retrieving city #494: majene
# Retrieving city #495: riacho de santana
# Retrieving city #496: coahuayana
# Retrieving city #497: kovur
# Retrieving city #498: medicine hat
# Retrieving city #499: banamba
# Retrieving city #500: kidal
# Retrieving city #501: ilo
# Retrieving city #502: kachikau
# Retrieving city #503: tarudant
# Retrieving city #504: saint-prosper
# Retrieving city #505: maragogi
# Retrieving city #506: pueblo rico
# Retrieving city #507: alice springs
# Retrieving city #508: chegdomyn
# Retrieving city #509: nampula
# Retrieving city #510: bonavista
# Retrieving city #511: gallup
# Retrieving city #512: birao
# Retrieving city #513: lolua
# Retrieving city #514: itapaci
# Retrieving city #515: bodden town
# Retrieving city #516: northam
# Retrieving city #517: omsukchan
# Retrieving city #518: puerto colombia
# Retrieving city #519: catu
# Retrieving city #520: dolbeau
# Retrieving city #521: nemuro
# Retrieving city #522: ojinaga
# Retrieving city #523: comodoro rivadavia
# Retrieving city #524: sechura
# Retrieving city #525: sawtell
# Retrieving city #526: kostomuksha
# Retrieving city #527: kearney
# Retrieving city #528: igarka
# Retrieving city #529: cambridge
# Retrieving city #530: berlevag
# Retrieving city #531: the valley
# Retrieving city #532: kamen-rybolov
# Retrieving city #533: palembang
# Retrieving city #534: tezu
# Retrieving city #535: rajec
# Retrieving city #536: techirghiol
# Retrieving city #537: laguna
# Retrieving city #538: andevoranto
# Retrieving city #539: kampot
# Retrieving city #540: taft
# Retrieving city #541: abeche
# Retrieving city #542: zhezkazgan
# Retrieving city #543: coquimbo
# Retrieving city #544: lorengau
# Retrieving city #545: champerico
# Retrieving city #546: half moon bay
# Retrieving city #547: asau
# Retrieving city #548: laukaa
# Retrieving city #549: beipiao
# Retrieving city #550: nhulunbuy
# Retrieving city #551: barawe
# Retrieving city #552: whitianga
# Retrieving city #553: huarmey
# Retrieving city #554: san luis
# Retrieving city #555: ornes
# Retrieving city #556: jardim
# Retrieving city #557: paradwip
# Retrieving city #558: vestmannaeyjar
# Retrieving city #559: la ronge
# Retrieving city #560: sangar
# Retrieving city #561: acari
# Retrieving city #562: tautira
# Retrieving city #563: bongandanga
# Retrieving city #564: tutoia
# Retrieving city #565: teguldet
# Retrieving city #566: daru
# Retrieving city #567: kathmandu
# Retrieving city #568: evensk
# Retrieving city #569: yarkovo
# Retrieving city #570: kashan
# Retrieving city #571: kontagora
# Retrieving city #572: xichang
# Retrieving city #573: lagoa
# Retrieving city #574: cocobeach
# Retrieving city #575: krasnoye
# Retrieving city #576: muzhi
# Retrieving city #577: pinillos
# Retrieving city #578: buluang
# Retrieving city #579: makakilo city
# Retrieving city #580: moroni
# Retrieving city #581: henties bay
# Retrieving city #582: lyndon
# Retrieving city #583: tazovskiy
# Retrieving city #584: vuktyl
# Retrieving city #585: sawakin
# Retrieving city #586: jambi
# Retrieving city #587: udachnyy
# Retrieving city #588: padang
# Retrieving city #589: tromso
# Retrieving city #590: rawson
# Retrieving city #591: sur
# Retrieving city #592: imeni poliny osipenko
# Retrieving city #593: matamoros
# Retrieving city #594: port-de-bouc
# Retrieving city #595: vila velha
# Retrieving city #596: biloela
# Retrieving city #597: mana
# Retrieving city #598: aasiaat
# Retrieving city #599: ketchenery
# Retrieving city #600: ciocanesti
# -----
# Data retrieval complete.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "city": cities,
    "clouds": clouds,
    "country": country,
    "date": date,
    "humidity": humidity,
    "lat": lat,
    "lng": lng,
    "max temp": maxtemp,
    "windspeed": wind
}

weather_df = pd.DataFrame(weather_dict)
weather_df = weather_df.dropna(how='any')
final_citnum = weather_df['city'].count()
weather_df.to_csv("weatherdata.csv", index=False, header=True) 
print(f"There are {final_citnum} observations.")
weather_df
# Out:
# There are 539 observations.
#                city  clouds country          date  humidity    lat     lng  \
# 0            castro       0      CL  1.574440e+09      55.0 -42.48  -73.76
# 1    saint-philippe      90      CA  1.574440e+09      80.0  45.36  -73.48
# 3           rikitea      90      PF  1.574440e+09      85.0 -23.12 -134.97
# 4              hilo      90      US  1.574440e+09      83.0  19.71 -155.08
# 5          hermanus       5      ZA  1.574440e+09      75.0 -34.42   19.24
# ..              ...     ...     ...           ...       ...    ...     ...
# 594      vila velha      20      BR  1.574440e+09      55.0  -3.71  -38.60
# 595         biloela       0      AU  1.574440e+09      86.0 -24.40  150.51
# 596            mana     100      NG  1.574440e+09      18.0  13.03    5.27
# 597         aasiaat     100      GL  1.574440e+09      71.0  68.71  -52.87
# 599      ciocanesti      90      RO  1.574440e+09      64.0  44.60   25.85
#
#      max temp  windspeed
# 0       60.80       6.93
# 1       43.00      20.80
# 3       73.06      14.92
# 4       71.60       6.93
# 5       68.00       3.00
# ..        ...        ...
# 594     87.80      14.99
# 595     61.07       2.98
# 596     83.62       1.90
# 597      9.84       6.85
# 599     33.01      16.11
#
# [539 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.title("Latitude vs. Max Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.xlim(-90, 90)
plt.grid()
plt.scatter(weather_df['lat'], weather_df['max temp'], marker="o", facecolors="blue", edgecolors="red", alpha=0.75);
plt.savefig("temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.title("Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.xlim(-90, 90)
plt.grid()
plt.scatter(weather_df['lat'], weather_df['humidity'], marker="o", facecolors="blue", edgecolors="red", alpha=0.75);
plt.savefig("humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloud Cover (%)")
plt.xlim(-90, 90)
plt.grid()
plt.scatter(weather_df['lat'], weather_df['clouds'], marker="o", facecolors="blue", edgecolors="red", alpha=0.75);
plt.savefig("cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Windspeed (mph)")
plt.xlim(-90, 90)
plt.grid()
plt.scatter(weather_df['lat'], weather_df['windspeed'], marker="o", facecolors="blue", edgecolors="red", alpha=0.75);
plt.savefig("windspeed.png")
